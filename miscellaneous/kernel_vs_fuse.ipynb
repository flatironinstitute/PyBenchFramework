# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/1_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/5_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/10_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/15_jobs_4K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Random Reads (fuse, 4K)", 'read')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/1_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/5_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/10_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/15_jobs_4K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Random Reads (kernel, 4K)", 'read')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/1_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/5_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/10_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/15_jobs_64K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Random Reads (fuse, 64K)", 'read')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/1_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/5_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/10_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/15_jobs_64K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Random Reads (kernel, 64K)", 'read')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3524094_fuse/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Random Reads (fuse, 4M)", 'read')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randread/EC63/3538242/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Random Reads (kernel, 4M)", 'read')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/1_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/5_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/10_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/15_jobs_4K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Random Writes (fuse, 4K)", 'write')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/1_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/5_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/10_jobs_4K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/15_jobs_4K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Random Writes (kernel, 4K)", 'write')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/1_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/5_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/10_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/15_jobs_64K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Random Writes (fuse, 64K)", 'write')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/1_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/5_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/10_jobs_64K',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/15_jobs_64K',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Random Writes (kernel, 64K)", 'write')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3519426_fuse/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Random Writes (fuse, 4M)", 'write')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/randwrite/EC63/3538242/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Random Writes (kernel, 4M)", 'write')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3519426_fuse/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3519426_fuse/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3519426_fuse/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3519426_fuse/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Sequential Writes (fuse, 4M)", 'write')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3538242/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3538242/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3538242/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/write/EC63/3538242/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Sequential Writes (kernel, 4M)", 'write')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()

# %%
from plot_plus_new_parse_func import load_json_files
from plot_plus_new_parse_func import plot_data, parse_data
import re
import matplotlib.pyplot as plt

# Example usage


json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3519426_fuse/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3519426_fuse/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3519426_fuse/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3519426_fuse/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

xmaster_list, ymaster_list, y2master_list, run_list, plot_title = parse_data(json_data, "Sequential Reads (fuse, 4M)", 'read')

json_data = {}
directory_path = ['/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3538242/1_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3538242/5_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3538242/10_jobs_4M',
                  '/mnt/home/skrit/Documents/PyBenchFramework/results/read/EC63/3538242/15_jobs_4M',]

for item in directory_path:
    type_of_run = re.split(r'[/]\s*', item)
    type_of_run = type_of_run[len(type_of_run)-1]
    json_data[type_of_run] = load_json_files(item)

x1master_list, y1master_list, y12master_list, run1_list, plot1_title = parse_data(json_data, "Sequential Reads (kernel, 4M)", 'read')

# %%
fig, (ax, ax3) = plt.subplots(1, 2, figsize=(12, 6))
ax2 = ax.twinx()

for i in range(len(xmaster_list)):
    ax.plot(xmaster_list[i], ymaster_list[i], 'o', label=run_list[i])
    ax2.plot(xmaster_list[i], y2master_list[i], 'o', label=run_list[i])
    
ax2.set_ylabel("IOPS")
ax.set_xlabel('Node count')
ax.set_ylabel('MB/s')
ax.set_title(plot_title)
ax.legend(title='Type of run')
plt.xticks(rotation=45)

ax22 = ax3.twinx()

for i in range(len(x1master_list)):
    ax3.plot(x1master_list[i], y1master_list[i], 'o', label=run1_list[i])
    ax22.plot(x1master_list[i], y12master_list[i], 'o', label=run1_list[i])
    
ax22.set_ylabel("IOPS")
ax3.set_xlabel('Node count')
ax3.set_ylabel('MB/s')
ax3.set_title(plot1_title)
ax3.legend(title='Type of run')
plt.xticks(rotation=45)

# Determine the maximum values for both sets of y-data
max_y1 = max(max(y) for y in ymaster_list)
max_y2 = max(max(y) for y in y2master_list)
max_y3 = max(max(y) for y in y1master_list)
max_y4 = max(max(y) for y in y12master_list)

# Determine the 10% margin
max_y = max(max_y1, max_y3) * 1.1
max_y_secondary = max(max_y2, max_y4) * 1.1

# Set the same y-limits for both plots
ax.set_ylim(0, max_y)
ax3.set_ylim(0, max_y)
ax2.set_ylim(0, max_y_secondary)
ax22.set_ylim(0, max_y_secondary)

plt.tight_layout()
plt.show()
